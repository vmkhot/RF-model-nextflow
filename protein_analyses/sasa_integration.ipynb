# %%
import pandas as pd

# %%
df_all_prots = pd.read_csv("new_comparisons/RF/mapped_interactions_RF.tsv", sep='\t')
df_all_prots
# Out:
#                      chain_A A_AA A_pos A_atom              chain_B B_AA  \
# 0                        NaN    -     -    NaN                  NaN    -
# 1                        NaN    -     -    NaN                  NaN    -
# 2                        NaN    -     -    NaN                  NaN    -
# 3                        NaN    -     -    NaN                  NaN    -
# 4        #2//chain_id='A-53'  PRO   377     CB  #2//chain_id='A-60'  PHE
# ...                      ...  ...   ...    ...                  ...  ...
# 3170789                  NaN    -     -    NaN                  NaN    -
# 3170790                  NaN    -     -    NaN                  NaN    -
# 3170791                  NaN    -     -    NaN                  NaN    -
# 3170792                  NaN    -     -    NaN                  NaN    -
# 3170793                  NaN    -     -    NaN                  NaN    -
#
#         B_pos B_atom  overlap  distance  ... seq_position_A  feat_rank_B  \
# ...
